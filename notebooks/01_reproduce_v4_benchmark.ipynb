# %% [markdown]
# # Reproduce v4 benchmark
#
# This notebook regenerates the v4 data table and runs the v4 ablation benchmark.

# %%
# !pytest -q tests/test_selectivity_v4_data.py tests/test_selectivity_v4_features.py

# %%
# !python -m kira.experiments.selectivity_v4_data

# %%
# !python -m kira.experiments.run_selectivity_v4

# %%
import json, pandas as pd
summary = json.loads(open('results/selectivity_v4/summary.json').read())
pd.DataFrame(summary['ablations'])[['ablation','pooled_auroc','macro_pair_auroc','macro_pair_spearman']]
